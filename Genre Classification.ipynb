# %%
# %matplotlib inline
import itertools
import numpy, scipy, matplotlib.pyplot as plt, pandas, librosa,sklearn
import config

from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC

# %%
data_set=pandas.read_csv('https://raw.githubusercontent.com/alikaratana/Music-Genre-Classification/master/data_set.csv',index_col=False)
GENRES=['METAL', 'CLASSICAL', 'HIPHOP', 'BLUES', 'POP', 'REGGAE']

number_of_rows,number_of_cols = data_set.shape
data_set[:5].style
# Out:
# <style type="text/css">
# </style>
# <table id="T_e3937_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >meanZCR</th>
#       <th class="col_heading level0 col1" >stdZCR</th>
#       <th class="col_heading level0 col2" >meanSpecCentroid</th>
#       <th class="col_heading level0 col3" >stdSpecCentroid</th>
#       <th class="col_heading level0 col4" >meanSpecContrast</th>
#       <th class="col_heading level0 col5" >stdSpecContrast</th>
#       <th class="col_heading level0 col6" >meanSpecBandwidth</th>
#       <th class="col_heading level0 col7" >stdSpecBandwidth</th>
#       <th class="col_heading level0 col8" >meanSpecRollof</th>
#       <th class="col_heading level0 col9" >stdSpecRollof</th>
#       <th class="col_heading level0 col10" >meanMFCC_1</th>
#       <th class="col_heading level0 col11" >stdMFCC_1</th>
#       <th class="col_heading level0 col12" >meanMFCC_2</th>
#       <th class="col_heading level0 col13" >stdMFCC_2</th>
#       <th class="col_heading level0 col14" >meanMFCC_3</th>
#       <th class="col_heading level0 col15" >stdMFCC_3</th>
#       <th class="col_heading level0 col16" >meanMFCC_4</th>
#       <th class="col_heading level0 col17" >stdMFCC_4</th>
#       <th class="col_heading level0 col18" >meanMFCC_5</th>
#       <th class="col_heading level0 col19" >stdMFCC_5</th>
#       <th class="col_heading level0 col20" >meanMFCC_6</th>
#       <th class="col_heading level0 col21" >stdMFCC_6</th>
#       <th class="col_heading level0 col22" >meanMFCC_7</th>
#       <th class="col_heading level0 col23" >stdMFCC_7</th>
#       <th class="col_heading level0 col24" >meanMFCC_8</th>
#       <th class="col_heading level0 col25" >stdMFCC_8</th>
#       <th class="col_heading level0 col26" >meanMFCC_9</th>
#       <th class="col_heading level0 col27" >stdMFCC_9</th>
#       <th class="col_heading level0 col28" >meanMFCC_10</th>
#       <th class="col_heading level0 col29" >stdMFCC_10</th>
#       <th class="col_heading level0 col30" >meanMFCC_11</th>
#       <th class="col_heading level0 col31" >stdMFCC_11</th>
#       <th class="col_heading level0 col32" >meanMFCC_12</th>
#       <th class="col_heading level0 col33" >stdMFCC_12</th>
#       <th class="col_heading level0 col34" >meanMFCC_13</th>
#       <th class="col_heading level0 col35" >stdMFCC_13</th>
#       <th class="col_heading level0 col36" >genre</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e3937_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e3937_row0_col0" class="data row0 col0" >-0.451810</td>
#       <td id="T_e3937_row0_col1" class="data row0 col1" >-0.784343</td>
#       <td id="T_e3937_row0_col2" class="data row0 col2" >-0.381408</td>
#       <td id="T_e3937_row0_col3" class="data row0 col3" >-0.691147</td>
#       <td id="T_e3937_row0_col4" class="data row0 col4" >-0.093114</td>
#       <td id="T_e3937_row0_col5" class="data row0 col5" >0.371373</td>
#       <td id="T_e3937_row0_col6" class="data row0 col6" >-0.193567</td>
#       <td id="T_e3937_row0_col7" class="data row0 col7" >-0.572264</td>
#       <td id="T_e3937_row0_col8" class="data row0 col8" >-0.236668</td>
#       <td id="T_e3937_row0_col9" class="data row0 col9" >-0.455356</td>
#       <td id="T_e3937_row0_col10" class="data row0 col10" >0.151288</td>
#       <td id="T_e3937_row0_col11" class="data row0 col11" >-0.734165</td>
#       <td id="T_e3937_row0_col12" class="data row0 col12" >-0.142672</td>
#       <td id="T_e3937_row0_col13" class="data row0 col13" >-0.458952</td>
#       <td id="T_e3937_row0_col14" class="data row0 col14" >0.286323</td>
#       <td id="T_e3937_row0_col15" class="data row0 col15" >-0.543969</td>
#       <td id="T_e3937_row0_col16" class="data row0 col16" >-0.127472</td>
#       <td id="T_e3937_row0_col17" class="data row0 col17" >-0.543927</td>
#       <td id="T_e3937_row0_col18" class="data row0 col18" >0.353179</td>
#       <td id="T_e3937_row0_col19" class="data row0 col19" >-0.566260</td>
#       <td id="T_e3937_row0_col20" class="data row0 col20" >-0.453191</td>
#       <td id="T_e3937_row0_col21" class="data row0 col21" >-0.498744</td>
#       <td id="T_e3937_row0_col22" class="data row0 col22" >0.455135</td>
#       <td id="T_e3937_row0_col23" class="data row0 col23" >-0.220863</td>
#       <td id="T_e3937_row0_col24" class="data row0 col24" >-0.306257</td>
#       <td id="T_e3937_row0_col25" class="data row0 col25" >-0.394531</td>
#       <td id="T_e3937_row0_col26" class="data row0 col26" >0.090856</td>
#       <td id="T_e3937_row0_col27" class="data row0 col27" >-0.114378</td>
#       <td id="T_e3937_row0_col28" class="data row0 col28" >-0.174782</td>
#       <td id="T_e3937_row0_col29" class="data row0 col29" >-0.734013</td>
#       <td id="T_e3937_row0_col30" class="data row0 col30" >0.379757</td>
#       <td id="T_e3937_row0_col31" class="data row0 col31" >-0.826864</td>
#       <td id="T_e3937_row0_col32" class="data row0 col32" >0.065192</td>
#       <td id="T_e3937_row0_col33" class="data row0 col33" >-0.802478</td>
#       <td id="T_e3937_row0_col34" class="data row0 col34" >0.337965</td>
#       <td id="T_e3937_row0_col35" class="data row0 col35" >-0.644471</td>
#       <td id="T_e3937_row0_col36" class="data row0 col36" >blues</td>
#     </tr>
#     <tr>
#       <th id="T_e3937_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e3937_row1_col0" class="data row1 col0" >-0.766532</td>
#       <td id="T_e3937_row1_col1" class="data row1 col1" >-0.726759</td>
#       <td id="T_e3937_row1_col2" class="data row1 col2" >-0.559681</td>
#       <td id="T_e3937_row1_col3" class="data row1 col3" >-0.463433</td>
#       <td id="T_e3937_row1_col4" class="data row1 col4" >-0.202180</td>
#       <td id="T_e3937_row1_col5" class="data row1 col5" >0.294939</td>
#       <td id="T_e3937_row1_col6" class="data row1 col6" >-0.145536</td>
#       <td id="T_e3937_row1_col7" class="data row1 col7" >-0.414690</td>
#       <td id="T_e3937_row1_col8" class="data row1 col8" >-0.333817</td>
#       <td id="T_e3937_row1_col9" class="data row1 col9" >0.018836</td>
#       <td id="T_e3937_row1_col10" class="data row1 col10" >0.086555</td>
#       <td id="T_e3937_row1_col11" class="data row1 col11" >-0.609341</td>
#       <td id="T_e3937_row1_col12" class="data row1 col12" >0.296721</td>
#       <td id="T_e3937_row1_col13" class="data row1 col13" >-0.224597</td>
#       <td id="T_e3937_row1_col14" class="data row1 col14" >0.261529</td>
#       <td id="T_e3937_row1_col15" class="data row1 col15" >-0.379317</td>
#       <td id="T_e3937_row1_col16" class="data row1 col16" >0.212097</td>
#       <td id="T_e3937_row1_col17" class="data row1 col17" >-0.245181</td>
#       <td id="T_e3937_row1_col18" class="data row1 col18" >0.436715</td>
#       <td id="T_e3937_row1_col19" class="data row1 col19" >-0.481450</td>
#       <td id="T_e3937_row1_col20" class="data row1 col20" >-0.109102</td>
#       <td id="T_e3937_row1_col21" class="data row1 col21" >0.835014</td>
#       <td id="T_e3937_row1_col22" class="data row1 col22" >0.662994</td>
#       <td id="T_e3937_row1_col23" class="data row1 col23" >-0.082433</td>
#       <td id="T_e3937_row1_col24" class="data row1 col24" >-0.074960</td>
#       <td id="T_e3937_row1_col25" class="data row1 col25" >0.315861</td>
#       <td id="T_e3937_row1_col26" class="data row1 col26" >0.067346</td>
#       <td id="T_e3937_row1_col27" class="data row1 col27" >0.103460</td>
#       <td id="T_e3937_row1_col28" class="data row1 col28" >0.112254</td>
#       <td id="T_e3937_row1_col29" class="data row1 col29" >-0.627408</td>
#       <td id="T_e3937_row1_col30" class="data row1 col30" >0.466185</td>
#       <td id="T_e3937_row1_col31" class="data row1 col31" >-0.771852</td>
#       <td id="T_e3937_row1_col32" class="data row1 col32" >0.270596</td>
#       <td id="T_e3937_row1_col33" class="data row1 col33" >-0.480038</td>
#       <td id="T_e3937_row1_col34" class="data row1 col34" >0.389865</td>
#       <td id="T_e3937_row1_col35" class="data row1 col35" >-0.579460</td>
#       <td id="T_e3937_row1_col36" class="data row1 col36" >blues</td>
#     </tr>
#     <tr>
#       <th id="T_

# %%
from sklearn.model_selection import train_test_split

data_set_values=numpy.array(data_set)

train, test = train_test_split(data_set_values, test_size = 0.85,random_state=2,
                              stratify=data_set_values[:,number_of_cols-1])

train_x=train[:,:number_of_cols-1]
train_y=train[:,number_of_cols-1]

test_x=test[:,:number_of_cols-1]
test_y=test[:,number_of_cols-1]

print("Training data size: {}".format(train.shape))
print("Test data size: {}".format(test.shape))
# Out:
# Training data size: (90, 37)
# Test data size: (510, 37)

# %%
def confusion_matrix(cm, classes,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
   
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = numpy.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

def plot_cnf(model,dataset_x,dataset_y,GENRES):
    true_y=dataset_y
    true_x=dataset_x
    pred=model.predict(true_x)

    print("---------------PERFORMANCE ANALYSIS FOR THE MODEL----------------\n")

    print("Real Test dataset labels: \n{}\n".format(true_y))
    print("Predicted Test dataset labels: \n{}".format(pred))

    cnf_matrix=sklearn.metrics.confusion_matrix(true_y,pred)
    plt.figure()
    a=confusion_matrix(cnf_matrix,classes=GENRES,title='Confusion matrix')

# %%
results_knn=[]
for i in range(1,11):
    knn=KNeighborsClassifier(n_neighbors=i)
    knn.fit(train_x,train_y)
    results_knn.append(knn.score(test_x,test_y))
    
max_accuracy_knn=max(results_knn)
best_k=1+results_knn.index(max(results_knn))
print("Max Accuracy is {:.3f} on test dataset with {} neighbors.\n".format(max_accuracy_knn,best_k))

plt.plot(numpy.arange(1,11),results_knn)
plt.xlabel("n Neighbors")
plt.ylabel("Accuracy")


knn=KNeighborsClassifier(n_neighbors=best_k)
knn.fit(train_x,train_y)
print("Training Score: {:.3f}".format(knn.score(train_x,train_y)))
print("Test score: {:.3f}".format(knn.score(test_x,test_y)))  

plot_cnf(knn,test_x,test_y,GENRES)
# Out:
# Max Accuracy is 0.671 on test dataset with 8 neighbors.
#
# Training Score: 0.789
# Test score: 0.671
# ---------------PERFORMANCE ANALYSIS FOR THE MODEL----------------
#
# Real Test dataset labels:
# ['hiphop' 'blues' 'reggae' 'blues' 'hiphop' 'classical' 'blues' 'hiphop'
#  'reggae' 'blues' 'reggae' 'reggae' 'reggae' 'reggae' 'pop' 'pop' 'hiphop'
#  'reggae' 'blues' 'pop' 'metal' 'metal' 'pop' 'classical' 'pop'
#  'classical' 'metal' 'hiphop' 'classical' 'blues' 'metal' 'metal' 'reggae'
#  'reggae' 'reggae' 'hiphop' 'reggae' 'classical' 'metal' 'hiphop' 'reggae'
#  'pop' 'classical' 'classical' 'pop' 'metal' 'classical' 'reggae'
#  'classical' 'blues' 'metal' 'metal' 'classical' 'pop' 'reggae' 'metal'
#  'metal' 'pop' 'classical' 'metal' 'pop' 'blues' 'classical' 'blues'
#  'metal' 'metal' 'hiphop' 'hiphop' 'reggae' 'blues' 'classical' 'reggae'
#  'classical' 'reggae' 'metal' 'classical' 'hiphop' 'blues' 'metal'
#  'reggae' 'reggae' 'blues' 'blues' 'hiphop' 'reggae' 'metal' 'blues' 'pop'
#  'blues' 'blues' 'reggae' 'metal' 'classical' 'metal' 'blues' 'blues'
#  'pop' 'metal' 'metal' 'classical' 'blues' 'classical' 'pop' 'classical'
#  'metal' 'pop' 'hiphop' 'metal' 'reggae' 'metal' 'reggae' 'metal' 'blues'
#  'blues' 'pop' 'reggae' 'pop' 'hiphop' 'hiphop' 'reggae' 'metal' 'blues'
#  'pop' 'metal' 'classical' 'pop' 'hiphop' 'hiphop' 'reggae' 'pop' 'hiphop'
#  'pop' 'blues' 'metal' 'reggae' 'classical' 'metal' 'hiphop' 'classical'
#  'classical' 'blues' 'hiphop' 'reggae' 'pop' 'hiphop' 'metal' 'metal'
#  'hiphop' 'reggae' 'blues' 'metal' 'pop' 'classical' 'blues' 'pop' 'blues'
#  'pop' 'classical' 'pop' 'classical' 'hiphop' 'classical' 'blues' 'reggae'
#  'reggae' 'reggae' 'pop' 'classical' 'classical' 'pop' 'classical'
#  'hiphop' 'blues' 'blues' 'classical' 'blues' 'metal' 'pop' 'classical'
#  'metal' 'classical' 'classical' 'pop' 'pop' 'blues' 'reggae' 'blues'
#  'classical' 'pop' 'pop' 'hiphop' 'blues' 'pop' 'classical' 'hiphop' 'pop'
#  'classical' 'blues' 'reggae' 'hiphop' 'metal' 'reggae' 'metal' 'reggae'
#  'metal' 'metal' 'reggae' 'classical' 'blues' 'classical' 'metal' 'blues'
#  'pop' 'hiphop' 'reggae' 'reggae' 'reggae' 'blues' 'classical' 'blues'
#  'hiphop' 'metal' 'metal' 'reggae' 'metal' 'metal' 'blues' 'hiphop'
#  'blues' 'blues' 'blues' 'blues' 'blues' 'reggae' 'hiphop' 'reggae'
#  'metal' 'blues' 'reggae' 'blues' 'pop' 'reggae' 'blues' 'metal' 'reggae'
#  'blues' 'pop' 'reggae' 'reggae' 'classical' 'metal' 'hiphop' 'pop'
#  'metal' 'blues' 'reggae' 'hiphop' 'metal' 'hiphop' 'hiphop' 'reggae'
#  'hiphop' 'classical' 'metal' 'classical' 'hiphop' 'hiphop' 'pop'
#  'classical' 'metal' 'hiphop' 'reggae' 'blues' 'reggae' 'classical'
#  'metal' 'hiphop' 'blues' 'pop' 'pop' 'reggae' 'metal' 'classical'
#  'classical' 'pop' 'metal' 'classical' 'classical' 'pop' 'classical'
#  'reggae' 'classical' 'blues' 'reggae' 'hiphop' 'hiphop' 'classical'
#  'metal' 'hiphop' 'blues' 'classical' 'classical' 'pop' 'reggae'
#  'classical' 'reggae' 'pop' 'hiphop' 'pop' 'blues' 'pop' 'blues' 'pop'
#  'pop' 'pop' 'pop' 'hiphop' 'hiphop' 'hiphop' 'classical' 'blues' 'hiphop'
#  'metal' 'hiphop' 'metal' 'blues' 'hiphop' 'pop' 'classical' 'reggae'
#  'pop' 'classical' 'reggae' 'pop' 'pop' 'blues' 'pop' 'blues' 'hiphop'
#  'reggae' 'hiphop' 'hiphop' 'blues' 'pop' 'hiphop' 'classical' 'pop'
#  'metal' 'pop' 'classical' 'metal' 'reggae' 'classical' 'reggae' 'pop'
#  'reggae' 'classical' 'hiphop' 'pop' 'metal' 'pop' 'pop' 'classical'
#  'reggae' 'reggae' 'reggae' 'hiphop' 'metal' 'metal' 'classical' 'blues'
#  'metal' 'reggae' 'metal' 'metal' 'classical' 'metal' 'reggae' 'hiphop'
#  'pop' 'reggae' 'hiphop' 'metal' 'metal' 'hiphop' 'pop' 'hiphop' 'pop'
#  'reggae' 'hiphop' 'blues' 'blues' 'blues' 'hiphop' 'reggae' 'hiphop'
#  'blues' 'metal' 'blues' 'reggae' 'blues' 'reggae' 'metal' 'reggae'
#  'classical' 'hiphop' 'hiphop' 'classical' 'hiphop' 'reggae' 'metal'
#  'reggae' 'metal' 'hiphop' 'pop' 'classical' 'blues' 'metal' 'classical'
#  'classical' 'reggae' 'pop' 'pop' 'hiphop' 'hiphop' 'metal' 'blues'
#  'hiphop' 'pop' 'classical' 'blues' 'hiphop' 'blues' 'reggae' 'classical'
#  'hiphop' 'metal' 'metal' 'blues' 'hiphop' 'pop' 'hiphop' 'reggae'
#  'classical' 'classical' 'blues' 'classical' 'hiphop' 'hiphop' 'hiphop'
#  'blues' 'hiphop' 'hiphop' 'blues' 'pop' 'pop' 'pop' 'metal' 'blues'
#  'classical' 'pop' 'classical' 'blues' 'pop' 'hiphop' 'metal' 'blues'
#  'pop' 'classical' 'pop' 'hiphop' 'metal' 'reggae' 'pop' 'metal' 'blues'
#  'metal' 'metal' 'metal' 'hiphop' 'pop' 'classical' 'hiphop' 'classical'
#  'reggae' 'blues' 'blues' 'hiphop' 'reggae' 'hiphop' 'pop' 'metal' 'blues'
#  'pop' 'reggae' 'metal' 'hiphop' 'metal' 'reggae' 'classical' 'pop' 'pop'
#  'reggae' 'classical' 'blues' 'classical' 'classical' 'pop' 'blues'
#  'classical']
#
# Predicted Test dataset labels:
# ['reggae' 'blues' 'hiphop' 'reggae' 'hiphop' 'blues' 'hiphop' 'hiphop'
#  'reggae' 'blues' 'reggae' 'hiphop' 'reggae' 'reggae' 'pop' 'hiphop'
#  'hiphop' 'reggae' 'metal' 'pop' 'blues' 'metal' 'hiphop' 'classical'
#  'reggae' 'classical' 'metal' 'hiphop' 'classical' 'reggae' 'pop' 'metal'
#  'blues' 'reggae' 'reggae' 'pop' 'reggae' 'blues' 'metal' 'metal' 'reggae'
#  'pop' 'classical' 'classical' 'pop' 'metal' 'reggae' 'hiphop' 'classical'
#  'blues' 'pop' 'metal' 'classical' 'pop' 'reggae' 'metal' 'metal' 'pop'
#  'classical' 'metal' 'pop' 'blues' 'classical' 'hiphop' 'metal' 'hiphop'
#  'reggae' 'blues' 'reggae' 'blues' 'classical' 'reggae' 'classical'
#  'hiphop' 'metal' 'classical' 'reggae' 'blues' 'metal' 'blues' 'reggae'
#  'metal' 'reggae' 'hiphop' 'blues' 'metal' 'metal' 'pop' 'blues' 'metal'
#  'reggae' 'metal' 'classical' 'metal' 'metal' 'blues' 'pop' 'metal'
#  'metal' 'classical' 'classical' 'classical' 'pop' 'classical' 'metal'
#  'pop' 'pop' 'metal' 'hiphop' 'metal' 'pop' 'metal' 'blues' 'metal' 'pop'
#  'reggae' 'reggae' 'hiphop' 'hiphop' 'hiphop' 'metal' 'blues' 'pop'
#  'metal' 'pop' 'pop' 'hiphop' 'metal' 'hiphop' 'pop' 'pop' 'reggae'
#  'blues' 'metal' 'reggae' 'classical' 'metal' 'reggae' 'classical'
#  'classical' 'blues' 'hiphop' 'reggae' 'pop' 'hiphop' 'metal' 'metal'
#  'pop' 'reggae' 'metal' 'metal' 'reggae' 'classical' 'metal' 'pop'
#  'classical' 'pop' 'blues' 'pop' 'classical' 'blues' 'classical' 'blues'
#  'hiphop' 'hiphop' 'pop' 'pop' 'classical' 'classical' 'pop' 'classical'
#  'reggae' 'metal' 'metal' 'classical' 'blues' 'metal' 'pop' 'classical'
#  'metal' 'classical' 'classical' 'pop' 'pop' 'blues' 'blues' 'blues'
#  'classical' 'pop' 'hiphop' 'metal' 'blues' 'reggae' 'classical' 'hiphop'
#  'pop' 'blues' 'hiphop' 'metal' 'pop' 'metal' 'pop' 'metal' 'reggae'
#  'metal' 'metal' 'pop' 'classical' 'metal' 'classical' 'metal' 'metal'
#  'reggae' 'hiphop' 'blues' 'reggae' 'hiphop' 'blues' 'classical' 'blues'
#  'hiphop' 'metal' 'metal' 'hiphop' 'metal' 'metal' 'metal' 'pop' 'blues'
#  'metal' 'metal' 'blues' 'blues' 'hiphop' 'metal' 'reggae' 'metal' 'blues'
#  'pop' 'blues' 'pop' 'blues' 'metal' 'metal' 'reggae' 'metal' 'pop'
#  'blues' 'hiphop' 'classical' 'blues' 'hiphop' 'pop' 'metal' 'metal'
#  'blues' 'blues' 'metal' 'pop' 'metal' 'reggae' 'hiphop' 'classical'
#  'metal' 'blues' 'reggae' 'metal' 'pop' 'classical' 'metal' 'reggae'
#  'hiphop' 'metal' 'hiphop' 'classical' 'metal' 'hiphop' 'reggae' 'pop'
#  'pop' 'hiphop' 'blues' 'classical' 'classical' 'pop' 'metal' 'classical'
#  'classical' 'pop' 'classical' 'reggae' 'classical' 'blues' 'reggae' 'pop'
#  'hiphop' 'reggae' 'metal' 'metal' 'blues' 'classical' 'classical' 'pop'
#  'pop' 'classical' 'reggae' 'pop' 'hiphop' 'pop' 'reggae' 'pop' 'blues'
#  'reggae' 'pop' 'pop' 'pop' 'hiphop' 'hiphop' 'blues' 'classical' 'reggae'
#  'reggae' 'metal' 'blues' 'blues' 'blues' 'pop' 'pop' 'classical' 'hiphop'
#  'pop' 'classical' 'hiphop' 'pop' 'pop' 'metal' 'pop' 'blues' 'hiphop'
#  'reggae' 'blues' 'hiphop' 'metal' 'pop' 'metal' 'classical' 'reggae'
#  'metal' 'pop' 'blues' 'metal' 'reggae' 'classical' 'hiphop' 'hiphop'
#  'blues' 'classical' 'pop' 'pop' 'metal' 'pop' 'pop' 'classical' 'hiphop'
#  'reggae' 'reggae' 'hiphop' 'blues' 'metal' 'classical' 'hiphop' 'metal'
#  'reggae' 'metal' 'metal' 'classical' 'metal' 'pop' 'hiphop' 'pop'
#  'reggae' 'metal' 'metal' 'metal' 'pop' 'pop' 'metal' 'pop' 'reggae'
#  'hiphop' 'metal' 'metal' 'blues' 'hiphop' 'reggae' 'metal' 'reggae'
#  'metal' 'metal' 'blues' 'blues' 'hiphop' 'metal' 'reggae' 'classical'
#  'pop' 'metal' 'classical' 'hiphop' 'reggae' 'metal' 'reggae' 'metal'
#  'hiphop' 'pop' 'classical' 'blues' 'metal' 'classical' 'classical'
#  'reggae' 'reggae' 'pop' 'blues' 'reggae' 'metal' 'metal' 'reggae' 'pop'
#  'blues' 'blues' 'pop' 'reggae' 'reggae' 'classical' 'pop' 'metal' 'metal'
#  'blues' 'hiphop' 'pop' 'hiphop' 'reggae' 'classical' 'classical' 'blues'
#  'classical' 'hiphop' 'hiphop' 'hiphop' 'blues' 'metal' 'pop' 'blues'
#  'pop' 'pop' 'pop' 'metal' 'blues' 'classical' 'pop' 'classical' 'metal'
#  'hiphop' 'hiphop' 'metal' 'hiphop' 'pop' 'classical' 'pop' 'reggae'
#  'metal' 'hiphop' 'pop' 'metal' 'blues' 'metal' 'metal' 'metal' 'metal'
#  'pop' 'classical' 'blues' 'classical' 'hiphop' 'blues' 'hiphop' 'hiphop'
#  'hiphop' 'hiphop' 'pop' 'metal' 'blues' 'reggae' 'reggae' 'metal'
#  'hiphop' 'metal' 'blues' 'classical' 'pop' 'pop' 'reggae' 'classical'
#  'reggae' 'classical' 'classical' 'pop' 'metal' 'classical']

# %%
results_forest=[]
for i in range(2,20):
    forest=RandomForestClassifier(random_state=42,n_estimators=i)
    forest.fit(train_x,train_y)
    results_forest.append(forest.score(test_x,test_y))
    
max_accuracy_forest=max(results_forest)
best_n_est=2+results_forest.index(max(results_forest))
print("Max Accuracy is {:.3f} on test dataset with {} estimators.\n".format(max_accuracy_forest,best_n_est))

plt.plot(numpy.arange(2,20),results_forest)
plt.xlabel("n Estimators")
plt.ylabel("Accuracy")


forest=RandomForestClassifier(random_state=42,n_estimators=best_n_est)
forest.fit(train_x,train_y)
print("Training Score: {:.3f}".format(forest.score(train_x,train_y)))
print("Test score: {:.3f}".format(forest.score(test_x,test_y)))

plot_cnf(forest,test_x,test_y,GENRES)
# Out:
# Max Accuracy is 0.653 on test dataset with 19 estimators.
#
# Training Score: 1.000
# Test score: 0.653
# ---------------PERFORMANCE ANALYSIS FOR THE MODEL----------------
#
# Real Test dataset labels:
# ['hiphop' 'blues' 'reggae' 'blues' 'hiphop' 'classical' 'blues' 'hiphop'
#  'reggae' 'blues' 'reggae' 'reggae' 'reggae' 'reggae' 'pop' 'pop' 'hiphop'
#  'reggae' 'blues' 'pop' 'metal' 'metal' 'pop' 'classical' 'pop'
#  'classical' 'metal' 'hiphop' 'classical' 'blues' 'metal' 'metal' 'reggae'
#  'reggae' 'reggae' 'hiphop' 'reggae' 'classical' 'metal' 'hiphop' 'reggae'
#  'pop' 'classical' 'classical' 'pop' 'metal' 'classical' 'reggae'
#  'classical' 'blues' 'metal' 'metal' 'classical' 'pop' 'reggae' 'metal'
#  'metal' 'pop' 'classical' 'metal' 'pop' 'blues' 'classical' 'blues'
#  'metal' 'metal' 'hiphop' 'hiphop' 'reggae' 'blues' 'classical' 'reggae'
#  'classical' 'reggae' 'metal' 'classical' 'hiphop' 'blues' 'metal'
#  'reggae' 'reggae' 'blues' 'blues' 'hiphop' 'reggae' 'metal' 'blues' 'pop'
#  'blues' 'blues' 'reggae' 'metal' 'classical' 'metal' 'blues' 'blues'
#  'pop' 'metal' 'metal' 'classical' 'blues' 'classical' 'pop' 'classical'
#  'metal' 'pop' 'hiphop' 'metal' 'reggae' 'metal' 'reggae' 'metal' 'blues'
#  'blues' 'pop' 'reggae' 'pop' 'hiphop' 'hiphop' 'reggae' 'metal' 'blues'
#  'pop' 'metal' 'classical' 'pop' 'hiphop' 'hiphop' 'reggae' 'pop' 'hiphop'
#  'pop' 'blues' 'metal' 'reggae' 'classical' 'metal' 'hiphop' 'classical'
#  'classical' 'blues' 'hiphop' 'reggae' 'pop' 'hiphop' 'metal' 'metal'
#  'hiphop' 'reggae' 'blues' 'metal' 'pop' 'classical' 'blues' 'pop' 'blues'
#  'pop' 'classical' 'pop' 'classical' 'hiphop' 'classical' 'blues' 'reggae'
#  'reggae' 'reggae' 'pop' 'classical' 'classical' 'pop' 'classical'
#  'hiphop' 'blues' 'blues' 'classical' 'blues' 'metal' 'pop' 'classical'
#  'metal' 'classical' 'classical' 'pop' 'pop' 'blues' 'reggae' 'blues'
#  'classical' 'pop' 'pop' 'hiphop' 'blues' 'pop' 'classical' 'hiphop' 'pop'
#  'classical' 'blues' 'reggae' 'hiphop' 'metal' 'reggae' 'metal' 'reggae'
#  'metal' 'metal' 'reggae' 'classical' 'blues' 'classical' 'metal' 'blues'
#  'pop' 'hiphop' 'reggae' 'reggae' 'reggae' 'blues' 'classical' 'blues'
#  'hiphop' 'metal' 'metal' 'reggae' 'metal' 'metal' 'blues' 'hiphop'
#  'blues' 'blues' 'blues' 'blues' 'blues' 'reggae' 'hiphop' 'reggae'
#  'metal' 'blues' 'reggae' 'blues' 'pop' 'reggae' 'blues' 'metal' 'reggae'
#  'blues' 'pop' 'reggae' 'reggae' 'classical' 'metal' 'hiphop' 'pop'
#  'metal' 'blues' 'reggae' 'hiphop' 'metal' 'hiphop' 'hiphop' 'reggae'
#  'hiphop' 'classical' 'metal' 'classical' 'hiphop' 'hiphop' 'pop'
#  'classical' 'metal' 'hiphop' 'reggae' 'blues' 'reggae' 'classical'
#  'metal' 'hiphop' 'blues' 'pop' 'pop' 'reggae' 'metal' 'classical'
#  'classical' 'pop' 'metal' 'classical' 'classical' 'pop' 'classical'
#  'reggae' 'classical' 'blues' 'reggae' 'hiphop' 'hiphop' 'classical'
#  'metal' 'hiphop' 'blues' 'classical' 'classical' 'pop' 'reggae'
#  'classical' 'reggae' 'pop' 'hiphop' 'pop' 'blues' 'pop' 'blues' 'pop'
#  'pop' 'pop' 'pop' 'hiphop' 'hiphop' 'hiphop' 'classical' 'blues' 'hiphop'
#  'metal' 'hiphop' 'metal' 'blues' 'hiphop' 'pop' 'classical' 'reggae'
#  'pop' 'classical' 'reggae' 'pop' 'pop' 'blues' 'pop' 'blues' 'hiphop'
#  'reggae' 'hiphop' 'hiphop' 'blues' 'pop' 'hiphop' 'classical' 'pop'
#  'metal' 'pop' 'classical' 'metal' 'reggae' 'classical' 'reggae' 'pop'
#  'reggae' 'classical' 'hiphop' 'pop' 'metal' 'pop' 'pop' 'classical'
#  'reggae' 'reggae' 'reggae' 'hiphop' 'metal' 'metal' 'classical' 'blues'
#  'metal' 'reggae' 'metal' 'metal' 'classical' 'metal' 'reggae' 'hiphop'
#  'pop' 'reggae' 'hiphop' 'metal' 'metal' 'hiphop' 'pop' 'hiphop' 'pop'
#  'reggae' 'hiphop' 'blues' 'blues' 'blues' 'hiphop' 'reggae' 'hiphop'
#  'blues' 'metal' 'blues' 'reggae' 'blues' 'reggae' 'metal' 'reggae'
#  'classical' 'hiphop' 'hiphop' 'classical' 'hiphop' 'reggae' 'metal'
#  'reggae' 'metal' 'hiphop' 'pop' 'classical' 'blues' 'metal' 'classical'
#  'classical' 'reggae' 'pop' 'pop' 'hiphop' 'hiphop' 'metal' 'blues'
#  'hiphop' 'pop' 'classical' 'blues' 'hiphop' 'blues' 'reggae' 'classical'
#  'hiphop' 'metal' 'metal' 'blues' 'hiphop' 'pop' 'hiphop' 'reggae'
#  'classical' 'classical' 'blues' 'classical' 'hiphop' 'hiphop' 'hiphop'
#  'blues' 'hiphop' 'hiphop' 'blues' 'pop' 'pop' 'pop' 'metal' 'blues'
#  'classical' 'pop' 'classical' 'blues' 'pop' 'hiphop' 'metal' 'blues'
#  'pop' 'classical' 'pop' 'hiphop' 'metal' 'reggae' 'pop' 'metal' 'blues'
#  'metal' 'metal' 'metal' 'hiphop' 'pop' 'classical' 'hiphop' 'classical'
#  'reggae' 'blues' 'blues' 'hiphop' 'reggae' 'hiphop' 'pop' 'metal' 'blues'
#  'pop' 'reggae' 'metal' 'hiphop' 'metal' 'reggae' 'classical' 'pop' 'pop'
#  'reggae' 'classical' 'blues' 'classical' 'classical' 'pop' 'blues'
#  'classical']
#
# Predicted Test dataset labels:
# ['reggae' 'blues' 'reggae' 'blues' 'reggae' 'classical' 'reggae' 'reggae'
#  'reggae' 'blues' 'reggae' 'pop' 'reggae' 'reggae' 'pop' 'hiphop' 'hiphop'
#  'reggae' 'metal' 'pop' 'blues' 'metal' 'reggae' 'classical' 'hiphop'
#  'classical' 'metal' 'hiphop' 'classical' 'reggae' 'metal' 'metal'
#  'hiphop' 'reggae' 'reggae' 'hiphop' 'hiphop' 'classical' 'blues' 'metal'
#  'reggae' 'pop' 'blues' 'classical' 'pop' 'metal' 'classical' 'reggae'
#  'blues' 'reggae' 'metal' 'metal' 'classical' 'pop' 'reggae' 'metal'
#  'metal' 'pop' 'classical' 'metal' 'pop' 'blues' 'classical' 'reggae'
#  'metal' 'hiphop' 'reggae' 'reggae' 'reggae' 'reggae' 'classical' 'reggae'
#  'classical' 'reggae' 'metal' 'classical' 'hiphop' 'hiphop' 'metal'
#  'blues' 'reggae' 'metal' 'reggae' 'hiphop' 'classical' 'metal' 'metal'
#  'hiphop' 'blues' 'metal' 'reggae' 'metal' 'classical' 'metal' 'metal'
#  'hiphop' 'pop' 'metal' 'metal' 'classical' 'blues' 'classical' 'pop'
#  'classical' 'metal' 'pop' 'pop' 'metal' 'reggae' 'metal' 'pop' 'metal'
#  'reggae' 'metal' 'pop' 'reggae' 'pop' 'hiphop' 'hiphop' 'hiphop' 'metal'
#  'blues' 'pop' 'metal' 'hiphop' 'pop' 'hiphop' 'blues' 'hiphop' 'hiphop'
#  'hiphop' 'reggae' 'blues' 'metal' 'hiphop' 'blues' 'metal' 'pop'
#  'classical' 'blues' 'blues' 'reggae' 'reggae' 'pop' 'hiphop' 'metal'
#  'metal' 'pop' 'reggae' 'metal' 'metal' 'reggae' 'classical' 'metal' 'pop'
#  'classical' 'pop' 'blues' 'pop' 'classical' 'blues' 'classical' 'blues'
#  'hiphop' 'reggae' 'pop' 'pop' 'classical' 'reggae' 'pop' 'blues' 'hiphop'
#  'metal' 'metal' 'classical' 'blues' 'metal' 'pop' 'classical' 'metal'
#  'blues' 'classical' 'pop' 'pop' 'reggae' 'reggae' 'blues' 'blues' 'pop'
#  'hiphop' 'metal' 'blues' 'pop' 'classical' 'hiphop' 'pop' 'classical'
#  'hiphop' 'metal' 'pop' 'metal' 'pop' 'metal' 'reggae' 'metal' 'metal'
#  'hiphop' 'classical' 'blues' 'blues' 'metal' 'blues' 'hiphop' 'reggae'
#  'hiphop' 'hiphop' 'reggae' 'blues' 'blues' 'blues' 'hiphop' 'metal'
#  'metal' 'reggae' 'metal' 'metal' 'metal' 'pop' 'blues' 'metal' 'metal'
#  'blues' 'reggae' 'hiphop' 'blues' 'hiphop' 'metal' 'blues' 'pop' 'metal'
#  'pop' 'blues' 'metal' 'metal' 'reggae' 'metal' 'pop' 'reggae' 'hiphop'
#  'classical' 'blues' 'reggae' 'pop' 'metal' 'metal' 'blues' 'blues'
#  'metal' 'hiphop' 'metal' 'reggae' 'hiphop' 'classical' 'metal'
#  'classical' 'reggae' 'blues' 'pop' 'classical' 'metal' 'reggae' 'pop'
#  'metal' 'hiphop' 'classical' 'metal' 'hiphop' 'reggae' 'pop' 'pop'
#  'reggae' 'blues' 'classical' 'classical' 'pop' 'metal' 'classical'
#  'classical' 'pop' 'classical' 'reggae' 'classical' 'blues' 'reggae' 'pop'
#  'hiphop' 'reggae' 'metal' 'metal' 'hiphop' 'classical' 'classical' 'pop'
#  'pop' 'classical' 'reggae' 'pop' 'hiphop' 'reggae' 'hiphop' 'pop' 'blues'
#  'reggae' 'pop' 'pop' 'pop' 'hiphop' 'hiphop' 'hiphop' 'classical'
#  'reggae' 'reggae' 'metal' 'metal' 'metal' 'blues' 'pop' 'pop' 'classical'
#  'hiphop' 'pop' 'classical' 'pop' 'pop' 'pop' 'metal' 'pop' 'blues'
#  'hiphop' 'reggae' 'blues' 'hiphop' 'metal' 'pop' 'metal' 'classical'
#  'reggae' 'metal' 'pop' 'blues' 'blues' 'reggae' 'classical' 'reggae'
#  'hiphop' 'blues' 'classical' 'pop' 'pop' 'metal' 'pop' 'pop' 'classical'
#  'reggae' 'reggae' 'reggae' 'hiphop' 'blues' 'metal' 'classical' 'blues'
#  'metal' 'reggae' 'metal' 'metal' 'classical' 'metal' 'pop' 'pop' 'pop'
#  'reggae' 'metal' 'metal' 'hiphop' 'hiphop' 'pop' 'hiphop' 'pop' 'reggae'
#  'reggae' 'metal' 'metal' 'blues' 'hiphop' 'reggae' 'blues' 'reggae'
#  'metal' 'metal' 'blues' 'blues' 'reggae' 'metal' 'reggae' 'classical'
#  'pop' 'metal' 'classical' 'hiphop' 'reggae' 'blues' 'hiphop' 'metal'
#  'hiphop' 'pop' 'classical' 'blues' 'metal' 'classical' 'classical'
#  'reggae' 'reggae' 'pop' 'blues' 'pop' 'metal' 'metal' 'reggae' 'pop'
#  'classical' 'blues' 'pop' 'blues' 'reggae' 'classical' 'pop' 'metal'
#  'metal' 'blues' 'reggae' 'pop' 'hiphop' 'reggae' 'classical' 'classical'
#  'blues' 'blues' 'hiphop' 'reggae' 'hiphop' 'blues' 'metal' 'hiphop'
#  'blues' 'pop' 'pop' 'hiphop' 'metal' 'blues' 'classical' 'pop'
#  'classical' 'metal' 'reggae' 'hiphop' 'metal' 'hiphop' 'pop' 'reggae'
#  'pop' 'reggae' 'metal' 'hiphop' 'pop' 'metal' 'reggae' 'metal'
#  'classical' 'metal' 'metal' 'hiphop' 'classical' 'reggae' 'classical'
#  'hiphop' 'blues' 'blues' 'reggae' 'hiphop' 'hiphop' 'pop' 'metal' 'blues'
#  'reggae' 'reggae' 'metal' 'hiphop' 'metal' 'metal' 'classical' 'pop'
#  'pop' 'hiphop' 'classical' 'reggae' 'classical' 'classical' 'pop' 'metal'
#  'blues']

# %%
svm=SVC(C=100,gamma=0.08)
svm.fit(train_x,train_y)
print("Training Score: {:.3f}".format(svm.score(train_x,train_y)))
print("Test score: {:.3f}".format(svm.score(test_x,test_y)))

plot_cnf(svm,test_x,test_y,GENRES)
# Out:
# Training Score: 1.000
# Test score: 0.700
# ---------------PERFORMANCE ANALYSIS FOR THE MODEL----------------
#
# Real Test dataset labels:
# ['hiphop' 'blues' 'reggae' 'blues' 'hiphop' 'classical' 'blues' 'hiphop'
#  'reggae' 'blues' 'reggae' 'reggae' 'reggae' 'reggae' 'pop' 'pop' 'hiphop'
#  'reggae' 'blues' 'pop' 'metal' 'metal' 'pop' 'classical' 'pop'
#  'classical' 'metal' 'hiphop' 'classical' 'blues' 'metal' 'metal' 'reggae'
#  'reggae' 'reggae' 'hiphop' 'reggae' 'classical' 'metal' 'hiphop' 'reggae'
#  'pop' 'classical' 'classical' 'pop' 'metal' 'classical' 'reggae'
#  'classical' 'blues' 'metal' 'metal' 'classical' 'pop' 'reggae' 'metal'
#  'metal' 'pop' 'classical' 'metal' 'pop' 'blues' 'classical' 'blues'
#  'metal' 'metal' 'hiphop' 'hiphop' 'reggae' 'blues' 'classical' 'reggae'
#  'classical' 'reggae' 'metal' 'classical' 'hiphop' 'blues' 'metal'
#  'reggae' 'reggae' 'blues' 'blues' 'hiphop' 'reggae' 'metal' 'blues' 'pop'
#  'blues' 'blues' 'reggae' 'metal' 'classical' 'metal' 'blues' 'blues'
#  'pop' 'metal' 'metal' 'classical' 'blues' 'classical' 'pop' 'classical'
#  'metal' 'pop' 'hiphop' 'metal' 'reggae' 'metal' 'reggae' 'metal' 'blues'
#  'blues' 'pop' 'reggae' 'pop' 'hiphop' 'hiphop' 'reggae' 'metal' 'blues'
#  'pop' 'metal' 'classical' 'pop' 'hiphop' 'hiphop' 'reggae' 'pop' 'hiphop'
#  'pop' 'blues' 'metal' 'reggae' 'classical' 'metal' 'hiphop' 'classical'
#  'classical' 'blues' 'hiphop' 'reggae' 'pop' 'hiphop' 'metal' 'metal'
#  'hiphop' 'reggae' 'blues' 'metal' 'pop' 'classical' 'blues' 'pop' 'blues'
#  'pop' 'classical' 'pop' 'classical' 'hiphop' 'classical' 'blues' 'reggae'
#  'reggae' 'reggae' 'pop' 'classical' 'classical' 'pop' 'classical'
#  'hiphop' 'blues' 'blues' 'classical' 'blues' 'metal' 'pop' 'classical'
#  'metal' 'classical' 'classical' 'pop' 'pop' 'blues' 'reggae' 'blues'
#  'classical' 'pop' 'pop' 'hiphop' 'blues' 'pop' 'classical' 'hiphop' 'pop'
#  'classical' 'blues' 'reggae' 'hiphop' 'metal' 'reggae' 'metal' 'reggae'
#  'metal' 'metal' 'reggae' 'classical' 'blues' 'classical' 'metal' 'blues'
#  'pop' 'hiphop' 'reggae' 'reggae' 'reggae' 'blues' 'classical' 'blues'
#  'hiphop' 'metal' 'metal' 'reggae' 'metal' 'metal' 'blues' 'hiphop'
#  'blues' 'blues' 'blues' 'blues' 'blues' 'reggae' 'hiphop' 'reggae'
#  'metal' 'blues' 'reggae' 'blues' 'pop' 'reggae' 'blues' 'metal' 'reggae'
#  'blues' 'pop' 'reggae' 'reggae' 'classical' 'metal' 'hiphop' 'pop'
#  'metal' 'blues' 'reggae' 'hiphop' 'metal' 'hiphop' 'hiphop' 'reggae'
#  'hiphop' 'classical' 'metal' 'classical' 'hiphop' 'hiphop' 'pop'
#  'classical' 'metal' 'hiphop' 'reggae' 'blues' 'reggae' 'classical'
#  'metal' 'hiphop' 'blues' 'pop' 'pop' 'reggae' 'metal' 'classical'
#  'classical' 'pop' 'metal' 'classical' 'classical' 'pop' 'classical'
#  'reggae' 'classical' 'blues' 'reggae' 'hiphop' 'hiphop' 'classical'
#  'metal' 'hiphop' 'blues' 'classical' 'classical' 'pop' 'reggae'
#  'classical' 'reggae' 'pop' 'hiphop' 'pop' 'blues' 'pop' 'blues' 'pop'
#  'pop' 'pop' 'pop' 'hiphop' 'hiphop' 'hiphop' 'classical' 'blues' 'hiphop'
#  'metal' 'hiphop' 'metal' 'blues' 'hiphop' 'pop' 'classical' 'reggae'
#  'pop' 'classical' 'reggae' 'pop' 'pop' 'blues' 'pop' 'blues' 'hiphop'
#  'reggae' 'hiphop' 'hiphop' 'blues' 'pop' 'hiphop' 'classical' 'pop'
#  'metal' 'pop' 'classical' 'metal' 'reggae' 'classical' 'reggae' 'pop'
#  'reggae' 'classical' 'hiphop' 'pop' 'metal' 'pop' 'pop' 'classical'
#  'reggae' 'reggae' 'reggae' 'hiphop' 'metal' 'metal' 'classical' 'blues'
#  'metal' 'reggae' 'metal' 'metal' 'classical' 'metal' 'reggae' 'hiphop'
#  'pop' 'reggae' 'hiphop' 'metal' 'metal' 'hiphop' 'pop' 'hiphop' 'pop'
#  'reggae' 'hiphop' 'blues' 'blues' 'blues' 'hiphop' 'reggae' 'hiphop'
#  'blues' 'metal' 'blues' 'reggae' 'blues' 'reggae' 'metal' 'reggae'
#  'classical' 'hiphop' 'hiphop' 'classical' 'hiphop' 'reggae' 'metal'
#  'reggae' 'metal' 'hiphop' 'pop' 'classical' 'blues' 'metal' 'classical'
#  'classical' 'reggae' 'pop' 'pop' 'hiphop' 'hiphop' 'metal' 'blues'
#  'hiphop' 'pop' 'classical' 'blues' 'hiphop' 'blues' 'reggae' 'classical'
#  'hiphop' 'metal' 'metal' 'blues' 'hiphop' 'pop' 'hiphop' 'reggae'
#  'classical' 'classical' 'blues' 'classical' 'hiphop' 'hiphop' 'hiphop'
#  'blues' 'hiphop' 'hiphop' 'blues' 'pop' 'pop' 'pop' 'metal' 'blues'
#  'classical' 'pop' 'classical' 'blues' 'pop' 'hiphop' 'metal' 'blues'
#  'pop' 'classical' 'pop' 'hiphop' 'metal' 'reggae' 'pop' 'metal' 'blues'
#  'metal' 'metal' 'metal' 'hiphop' 'pop' 'classical' 'hiphop' 'classical'
#  'reggae' 'blues' 'blues' 'hiphop' 'reggae' 'hiphop' 'pop' 'metal' 'blues'
#  'pop' 'reggae' 'metal' 'hiphop' 'metal' 'reggae' 'classical' 'pop' 'pop'
#  'reggae' 'classical' 'blues' 'classical' 'classical' 'pop' 'blues'
#  'classical']
#
# Predicted Test dataset labels:
# ['hiphop' 'blues' 'reggae' 'reggae' 'hiphop' 'classical' 'reggae' 'reggae'
#  'reggae' 'blues' 'reggae' 'pop' 'reggae' 'reggae' 'pop' 'reggae' 'hiphop'
#  'reggae' 'blues' 'pop' 'metal' 'metal' 'hiphop' 'classical' 'reggae'
#  'classical' 'metal' 'hiphop' 'classical' 'reggae' 'pop' 'metal' 'reggae'
#  'reggae' 'reggae' 'hiphop' 'hiphop' 'blues' 'metal' 'metal' 'blues' 'pop'
#  'classical' 'classical' 'pop' 'metal' 'reggae' 'hiphop' 'classical'
#  'reggae' 'metal' 'metal' 'classical' 'pop' 'reggae' 'metal' 'metal' 'pop'
#  'classical' 'metal' 'pop' 'blues' 'classical' 'blues' 'metal' 'hiphop'
#  'reggae' 'hiphop' 'reggae' 'reggae' 'classical' 'pop' 'classical'
#  'hiphop' 'metal' 'classical' 'reggae' 'reggae' 'metal' 'blues' 'reggae'
#  'blues' 'reggae' 'hiphop' 'blues' 'hiphop' 'blues' 'reggae' 'classical'
#  'hiphop' 'reggae' 'metal' 'classical' 'metal' 'metal' 'blues' 'pop'
#  'metal' 'metal' 'classical' 'blues' 'classical' 'pop' 'classical' 'metal'
#  'pop' 'hiphop' 'metal' 'reggae' 'metal' 'hiphop' 'metal' 'blues' 'blues'
#  'hiphop' 'reggae' 'reggae' 'hiphop' 'hiphop' 'hiphop' 'metal' 'blues'
#  'pop' 'metal' 'pop' 'pop' 'hiphop' 'metal' 'hiphop' 'hiphop' 'hiphop'
#  'reggae' 'blues' 'metal' 'hiphop' 'classical' 'metal' 'pop' 'classical'
#  'classical' 'reggae' 'hiphop' 'reggae' 'pop' 'hiphop' 'metal' 'metal'
#  'hiphop' 'reggae' 'blues' 'metal' 'reggae' 'classical' 'metal' 'pop'
#  'classical' 'hiphop' 'classical' 'pop' 'classical' 'blues' 'classical'
#  'blues' 'hiphop' 'reggae' 'pop' 'pop' 'classical' 'reggae' 'pop'
#  'classical' 'hiphop' 'metal' 'metal' 'classical' 'blues' 'metal' 'pop'
#  'classical' 'blues' 'classical' 'classical' 'pop' 'pop' 'reggae' 'blues'
#  'blues' 'classical' 'pop' 'hiphop' 'hiphop' 'blues' 'reggae' 'classical'
#  'hiphop' 'pop' 'classical' 'hiphop' 'metal' 'hiphop' 'metal' 'pop'
#  'metal' 'reggae' 'metal' 'metal' 'hiphop' 'classical' 'blues' 'classical'
#  'metal' 'metal' 'reggae' 'hiphop' 'reggae' 'hiphop' 'hiphop' 'blues'
#  'classical' 'blues' 'hiphop' 'metal' 'metal' 'reggae' 'metal' 'hiphop'
#  'blues' 'hiphop' 'blues' 'blues' 'metal' 'blues' 'reggae' 'reggae'
#  'metal' 'reggae' 'metal' 'blues' 'hiphop' 'reggae' 'pop' 'blues' 'metal'
#  'metal' 'reggae' 'metal' 'hiphop' 'reggae' 'reggae' 'classical' 'blues'
#  'hiphop' 'pop' 'metal' 'metal' 'blues' 'blues' 'metal' 'pop' 'hiphop'
#  'reggae' 'hiphop' 'classical' 'metal' 'blues' 'reggae' 'blues' 'pop'
#  'classical' 'metal' 'hiphop' 'hiphop' 'blues' 'hiphop' 'classical'
#  'metal' 'hiphop' 'reggae' 'pop' 'pop' 'reggae' 'blues' 'classical'
#  'classical' 'pop' 'metal' 'classical' 'classical' 'pop' 'classical'
#  'hiphop' 'classical' 'reggae' 'hiphop' 'pop' 'hiphop' 'reggae' 'metal'
#  'metal' 'blues' 'classical' 'classical' 'pop' 'pop' 'classical' 'hiphop'
#  'reggae' 'metal' 'reggae' 'hiphop' 'hiphop' 'blues' 'reggae' 'pop' 'pop'
#  'pop' 'hiphop' 'hiphop' 'hiphop' 'classical' 'reggae' 'blues' 'metal'
#  'blues' 'metal' 'blues' 'pop' 'pop' 'classical' 'hiphop' 'pop'
#  'classical' 'hiphop' 'pop' 'pop' 'blues' 'pop' 'metal' 'hiphop' 'reggae'
#  'blues' 'hiphop' 'blues' 'pop' 'metal' 'classical' 'reggae' 'metal' 'pop'
#  'classical' 'metal' 'reggae' 'classical' 'reggae' 'hiphop' 'reggae'
#  'classical' 'hiphop' 'hiphop' 'metal' 'pop' 'pop' 'classical' 'reggae'
#  'reggae' 'reggae' 'hiphop' 'blues' 'metal' 'classical' 'blues' 'metal'
#  'reggae' 'metal' 'metal' 'classical' 'metal' 'hiphop' 'hiphop' 'pop'
#  'reggae' 'blues' 'metal' 'metal' 'hiphop' 'pop' 'hiphop' 'pop' 'reggae'
#  'reggae' 'metal' 'metal' 'classical' 'hiphop' 'reggae' 'blues' 'blues'
#  'metal' 'blues' 'blues' 'blues' 'reggae' 'metal' 'reggae' 'classical'
#  'hiphop' 'hiphop' 'classical' 'hiphop' 'hiphop' 'blues' 'hiphop' 'metal'
#  'hiphop' 'pop' 'classical' 'blues' 'metal' 'classical' 'classical'
#  'reggae' 'reggae' 'pop' 'blues' 'reggae' 'metal' 'metal' 'reggae'
#  'reggae' 'blues' 'blues' 'pop' 'blues' 'reggae' 'classical' 'hiphop'
#  'metal' 'metal' 'blues' 'reggae' 'pop' 'hiphop' 'reggae' 'classical'
#  'classical' 'blues' 'classical' 'hiphop' 'hiphop' 'hiphop' 'classical'
#  'blues' 'hiphop' 'blues' 'pop' 'pop' 'reggae' 'metal' 'blues' 'classical'
#  'pop' 'classical' 'blues' 'hiphop' 'hiphop' 'metal' 'hiphop' 'pop'
#  'classical' 'pop' 'reggae' 'metal' 'hiphop' 'pop' 'metal' 'reggae'
#  'metal' 'metal' 'metal' 'hiphop' 'hiphop' 'classical' 'reggae'
#  'classical' 'hiphop' 'blues' 'hiphop' 'reggae' 'hiphop' 'hiphop' 'pop'
#  'metal' 'blues' 'reggae' 'reggae' 'metal' 'hiphop' 'metal' 'blues'
#  'classical' 'pop' 'pop' 'pop' 'classical' 'reggae' 'classical'
#  'classical' 'pop' 'blues' 'classical']

# %%
neural=MLPClassifier(max_iter=400,random_state=2,hidden_layer_sizes=[40,40])
neural.fit(train_x,train_y)
print("Training Score: {:.3f}".format(neural.score(train_x,train_y)))
print("Test score: {:.3f}".format(neural.score(test_x,test_y)))

plot_cnf(neural,test_x,test_y,GENRES)
# Out:
# D:\Anaconda\envs\tf\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (400) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Training Score: 1.000
# Test score: 0.676
# ---------------PERFORMANCE ANALYSIS FOR THE MODEL----------------
#
# Real Test dataset labels:
# ['hiphop' 'blues' 'reggae' 'blues' 'hiphop' 'classical' 'blues' 'hiphop'
#  'reggae' 'blues' 'reggae' 'reggae' 'reggae' 'reggae' 'pop' 'pop' 'hiphop'
#  'reggae' 'blues' 'pop' 'metal' 'metal' 'pop' 'classical' 'pop'
#  'classical' 'metal' 'hiphop' 'classical' 'blues' 'metal' 'metal' 'reggae'
#  'reggae' 'reggae' 'hiphop' 'reggae' 'classical' 'metal' 'hiphop' 'reggae'
#  'pop' 'classical' 'classical' 'pop' 'metal' 'classical' 'reggae'
#  'classical' 'blues' 'metal' 'metal' 'classical' 'pop' 'reggae' 'metal'
#  'metal' 'pop' 'classical' 'metal' 'pop' 'blues' 'classical' 'blues'
#  'metal' 'metal' 'hiphop' 'hiphop' 'reggae' 'blues' 'classical' 'reggae'
#  'classical' 'reggae' 'metal' 'classical' 'hiphop' 'blues' 'metal'
#  'reggae' 'reggae' 'blues' 'blues' 'hiphop' 'reggae' 'metal' 'blues' 'pop'
#  'blues' 'blues' 'reggae' 'metal' 'classical' 'metal' 'blues' 'blues'
#  'pop' 'metal' 'metal' 'classical' 'blues' 'classical' 'pop' 'classical'
#  'metal' 'pop' 'hiphop' 'metal' 'reggae' 'metal' 'reggae' 'metal' 'blues'
#  'blues' 'pop' 'reggae' 'pop' 'hiphop' 'hiphop' 'reggae' 'metal' 'blues'
#  'pop' 'metal' 'classical' 'pop' 'hiphop' 'hiphop' 'reggae' 'pop' 'hiphop'
#  'pop' 'blues' 'metal' 'reggae' 'classical' 'metal' 'hiphop' 'classical'
#  'classical' 'blues' 'hiphop' 'reggae' 'pop' 'hiphop' 'metal' 'metal'
#  'hiphop' 'reggae' 'blues' 'metal' 'pop' 'classical' 'blues' 'pop' 'blues'
#  'pop' 'classical' 'pop' 'classical' 'hiphop' 'classical' 'blues' 'reggae'
#  'reggae' 'reggae' 'pop' 'classical' 'classical' 'pop' 'classical'
#  'hiphop' 'blues' 'blues' 'classical' 'blues' 'metal' 'pop' 'classical'
#  'metal' 'classical' 'classical' 'pop' 'pop' 'blues' 'reggae' 'blues'
#  'classical' 'pop' 'pop' 'hiphop' 'blues' 'pop' 'classical' 'hiphop' 'pop'
#  'classical' 'blues' 'reggae' 'hiphop' 'metal' 'reggae' 'metal' 'reggae'
#  'metal' 'metal' 'reggae' 'classical' 'blues' 'classical' 'metal' 'blues'
#  'pop' 'hiphop' 'reggae' 'reggae' 'reggae' 'blues' 'classical' 'blues'
#  'hiphop' 'metal' 'metal' 'reggae' 'metal' 'metal' 'blues' 'hiphop'
#  'blues' 'blues' 'blues' 'blues' 'blues' 'reggae' 'hiphop' 'reggae'
#  'metal' 'blues' 'reggae' 'blues' 'pop' 'reggae' 'blues' 'metal' 'reggae'
#  'blues' 'pop' 'reggae' 'reggae' 'classical' 'metal' 'hiphop' 'pop'
#  'metal' 'blues' 'reggae' 'hiphop' 'metal' 'hiphop' 'hiphop' 'reggae'
#  'hiphop' 'classical' 'metal' 'classical' 'hiphop' 'hiphop' 'pop'
#  'classical' 'metal' 'hiphop' 'reggae' 'blues' 'reggae' 'classical'
#  'metal' 'hiphop' 'blues' 'pop' 'pop' 'reggae' 'metal' 'classical'
#  'classical' 'pop' 'metal' 'classical' 'classical' 'pop' 'classical'
#  'reggae' 'classical' 'blues' 'reggae' 'hiphop' 'hiphop' 'classical'
#  'metal' 'hiphop' 'blues' 'classical' 'classical' 'pop' 'reggae'
#  'classical' 'reggae' 'pop' 'hiphop' 'pop' 'blues' 'pop' 'blues' 'pop'
#  'pop' 'pop' 'pop' 'hiphop' 'hiphop' 'hiphop' 'classical' 'blues' 'hiphop'
#  'metal' 'hiphop' 'metal' 'blues' 'hiphop' 'pop' 'classical' 'reggae'
#  'pop' 'classical' 'reggae' 'pop' 'pop' 'blues' 'pop' 'blues' 'hiphop'
#  'reggae' 'hiphop' 'hiphop' 'blues' 'pop' 'hiphop' 'classical' 'pop'
#  'metal' 'pop' 'classical' 'metal' 'reggae' 'classical' 'reggae' 'pop'
#  'reggae' 'classical' 'hiphop' 'pop' 'metal' 'pop' 'pop' 'classical'
#  'reggae' 'reggae' 'reggae' 'hiphop' 'metal' 'metal' 'classical' 'blues'
#  'metal' 'reggae' 'metal' 'metal' 'classical' 'metal' 'reggae' 'hiphop'
#  'pop' 'reggae' 'hiphop' 'metal' 'metal' 'hiphop' 'pop' 'hiphop' 'pop'
#  'reggae' 'hiphop' 'blues' 'blues' 'blues' 'hiphop' 'reggae' 'hiphop'
#  'blues' 'metal' 'blues' 'reggae' 'blues' 'reggae' 'metal' 'reggae'
#  'classical' 'hiphop' 'hiphop' 'classical' 'hiphop' 'reggae' 'metal'
#  'reggae' 'metal' 'hiphop' 'pop' 'classical' 'blues' 'metal' 'classical'
#  'classical' 'reggae' 'pop' 'pop' 'hiphop' 'hiphop' 'metal' 'blues'
#  'hiphop' 'pop' 'classical' 'blues' 'hiphop' 'blues' 'reggae' 'classical'
#  'hiphop' 'metal' 'metal' 'blues' 'hiphop' 'pop' 'hiphop' 'reggae'
#  'classical' 'classical' 'blues' 'classical' 'hiphop' 'hiphop' 'hiphop'
#  'blues' 'hiphop' 'hiphop' 'blues' 'pop' 'pop' 'pop' 'metal' 'blues'
#  'classical' 'pop' 'classical' 'blues' 'pop' 'hiphop' 'metal' 'blues'
#  'pop' 'classical' 'pop' 'hiphop' 'metal' 'reggae' 'pop' 'metal' 'blues'
#  'metal' 'metal' 'metal' 'hiphop' 'pop' 'classical' 'hiphop' 'classical'
#  'reggae' 'blues' 'blues' 'hiphop' 'reggae' 'hiphop' 'pop' 'metal' 'blues'
#  'pop' 'reggae' 'metal' 'hiphop' 'metal' 'reggae' 'classical' 'pop' 'pop'
#  'reggae' 'classical' 'blues' 'classical' 'classical' 'pop' 'blues'
#  'classical']
#
# Predicted Test dataset labels:
# ['hiphop' 'blues' 'reggae' 'blues' 'hiphop' 'classical' 'reggae' 'hiphop'
#  'reggae' 'reggae' 'pop' 'pop' 'reggae' 'reggae' 'pop' 'reggae' 'hiphop'
#  'reggae' 'blues' 'pop' 'metal' 'metal' 'reggae' 'classical' 'hiphop'
#  'classical' 'hiphop' 'hiphop' 'classical' 'reggae' 'pop' 'metal' 'reggae'
#  'hiphop' 'reggae' 'hiphop' 'hiphop' 'blues' 'hiphop' 'metal' 'blues'
#  'pop' 'blues' 'classical' 'pop' 'metal' 'classical' 'hiphop' 'classical'
#  'reggae' 'metal' 'hiphop' 'classical' 'pop' 'reggae' 'metal' 'metal'
#  'pop' 'classical' 'metal' 'reggae' 'blues' 'classical' 'blues' 'metal'
#  'hiphop' 'hiphop' 'reggae' 'hiphop' 'blues' 'classical' 'reggae'
#  'classical' 'hiphop' 'metal' 'classical' 'reggae' 'reggae' 'metal'
#  'blues' 'reggae' 'metal' 'blues' 'hiphop' 'reggae' 'metal' 'metal' 'pop'
#  'classical' 'metal' 'reggae' 'metal' 'classical' 'metal' 'metal' 'blues'
#  'pop' 'metal' 'metal' 'classical' 'classical' 'classical' 'pop'
#  'classical' 'metal' 'pop' 'hiphop' 'metal' 'reggae' 'metal' 'hiphop'
#  'metal' 'blues' 'blues' 'pop' 'reggae' 'reggae' 'hiphop' 'hiphop'
#  'hiphop' 'metal' 'blues' 'pop' 'metal' 'pop' 'pop' 'hiphop' 'metal'
#  'hiphop' 'pop' 'hiphop' 'reggae' 'blues' 'metal' 'hiphop' 'classical'
#  'metal' 'reggae' 'classical' 'classical' 'blues' 'reggae' 'reggae' 'pop'
#  'hiphop' 'metal' 'metal' 'pop' 'reggae' 'metal' 'metal' 'reggae'
#  'classical' 'metal' 'pop' 'classical' 'reggae' 'reggae' 'pop' 'classical'
#  'blues' 'classical' 'blues' 'hiphop' 'reggae' 'pop' 'pop' 'classical'
#  'reggae' 'pop' 'classical' 'hiphop' 'metal' 'metal' 'classical' 'blues'
#  'metal' 'pop' 'classical' 'metal' 'classical' 'classical' 'pop' 'pop'
#  'reggae' 'blues' 'reggae' 'classical' 'pop' 'hiphop' 'hiphop' 'metal'
#  'reggae' 'classical' 'pop' 'pop' 'classical' 'hiphop' 'metal' 'hiphop'
#  'metal' 'pop' 'metal' 'reggae' 'metal' 'metal' 'hiphop' 'classical'
#  'metal' 'classical' 'metal' 'metal' 'reggae' 'hiphop' 'reggae' 'hiphop'
#  'hiphop' 'blues' 'blues' 'blues' 'hiphop' 'metal' 'metal' 'reggae'
#  'metal' 'metal' 'blues' 'hiphop' 'blues' 'metal' 'metal' 'blues' 'reggae'
#  'hiphop' 'metal' 'reggae' 'metal' 'blues' 'reggae' 'reggae' 'hiphop'
#  'classical' 'metal' 'metal' 'reggae' 'blues' 'pop' 'reggae' 'reggae'
#  'classical' 'blues' 'hiphop' 'pop' 'metal' 'metal' 'blues' 'blues'
#  'metal' 'pop' 'hiphop' 'pop' 'hiphop' 'classical' 'metal' 'blues'
#  'reggae' 'blues' 'pop' 'classical' 'metal' 'hiphop' 'reggae' 'metal'
#  'hiphop' 'classical' 'metal' 'hiphop' 'reggae' 'pop' 'pop' 'reggae'
#  'blues' 'classical' 'classical' 'pop' 'metal' 'classical' 'classical'
#  'pop' 'classical' 'hiphop' 'classical' 'reggae' 'hiphop' 'pop' 'hiphop'
#  'reggae' 'metal' 'metal' 'blues' 'classical' 'classical' 'pop' 'pop'
#  'classical' 'blues' 'pop' 'metal' 'pop' 'reggae' 'hiphop' 'blues'
#  'reggae' 'pop' 'pop' 'pop' 'hiphop' 'hiphop' 'hiphop' 'classical'
#  'reggae' 'blues' 'metal' 'blues' 'metal' 'reggae' 'hiphop' 'pop'
#  'classical' 'hiphop' 'pop' 'classical' 'hiphop' 'pop' 'pop' 'metal' 'pop'
#  'blues' 'hiphop' 'reggae' 'blues' 'hiphop' 'blues' 'pop' 'metal'
#  'classical' 'reggae' 'metal' 'pop' 'classical' 'metal' 'reggae'
#  'classical' 'reggae' 'hiphop' 'blues' 'classical' 'pop' 'pop' 'metal'
#  'pop' 'pop' 'classical' 'reggae' 'reggae' 'reggae' 'hiphop' 'reggae'
#  'metal' 'classical' 'blues' 'metal' 'pop' 'metal' 'metal' 'classical'
#  'metal' 'hiphop' 'hiphop' 'pop' 'pop' 'metal' 'metal' 'hiphop' 'hiphop'
#  'pop' 'hiphop' 'pop' 'reggae' 'hiphop' 'metal' 'metal' 'classical'
#  'hiphop' 'reggae' 'metal' 'reggae' 'metal' 'blues' 'blues' 'blues'
#  'hiphop' 'metal' 'reggae' 'classical' 'hiphop' 'hiphop' 'classical'
#  'hiphop' 'hiphop' 'blues' 'hiphop' 'metal' 'hiphop' 'pop' 'classical'
#  'classical' 'metal' 'classical' 'classical' 'reggae' 'reggae' 'pop'
#  'blues' 'reggae' 'metal' 'metal' 'reggae' 'reggae' 'pop' 'blues' 'pop'
#  'blues' 'reggae' 'classical' 'hiphop' 'metal' 'metal' 'blues' 'reggae'
#  'pop' 'hiphop' 'reggae' 'classical' 'classical' 'blues' 'blues' 'hiphop'
#  'hiphop' 'hiphop' 'reggae' 'metal' 'hiphop' 'blues' 'pop' 'pop' 'pop'
#  'metal' 'blues' 'classical' 'pop' 'classical' 'blues' 'pop' 'hiphop'
#  'metal' 'hiphop' 'pop' 'classical' 'pop' 'reggae' 'metal' 'hiphop' 'pop'
#  'metal' 'reggae' 'metal' 'metal' 'metal' 'hiphop' 'hiphop' 'classical'
#  'reggae' 'classical' 'hiphop' 'blues' 'blues' 'reggae' 'hiphop' 'hiphop'
#  'pop' 'hiphop' 'reggae' 'reggae' 'reggae' 'metal' 'hiphop' 'metal'
#  'blues' 'classical' 'pop' 'pop' 'pop' 'classical' 'reggae' 'classical'
#  'classical' 'pop' 'blues' 'classical']
